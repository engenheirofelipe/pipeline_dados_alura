# %%
path_json = '../data_raw/dados_empresaA.json'

# %%
# Lendo o arquivo json e fazendo o print do readline

with open(path_json, 'r') as file:
    print(file.readline())
# Out:
# [{"Nome do Produto":"Blush em p\u00f3","Categoria do Produto":"Eletrodom\u00e9sticos","Pre\u00e7o do Produto (R$)":79.41,"Quantidade em Estoque":7,"Filial":"Filial 7"},

# %%
# Lendo o arquivo json e guardando em uma variável chamada dados.
with open(path_json, 'r') as file:
    dados = file.readline()
    print(dados)
# Out:
# [{"Nome do Produto":"Blush em p\u00f3","Categoria do Produto":"Eletrodom\u00e9sticos","Pre\u00e7o do Produto (R$)":79.41,"Quantidade em Estoque":7,"Filial":"Filial 7"},

# %%
# Verifica o tipo da variável dados

type(dados)
# Out:
# str

# %%
# Lendo o arquivo json com json.load
import json

with open(path_json, 'r') as file:
    dados_json = json.load(file)

# %%
dados_json[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
# Verificando o tipo de dados de dados_json, no caso é uma lista

type(dados_json)
# Out:
# list

# %%
# Verificando o tipo de dado que está dentro da lista, no caso é um dicionário
type(dados_json[0])
# Out:
# dict

# %%
# Adicionando caminho do arquivo em csv 

path_csv = '../data_raw/dados_empresaB.csv'

# Lendo o arquivo com readlines e guardando em uma variável dados_csv

with open(path_csv, 'r') as file:
    dados_csv = file.readlines()

# %%
dados_csv[0]
# Out:
# 'Nome do Item,ClassificaÃ§Ã£o do Produto,Valor em Reais (R$),Quantidade em Estoque,Nome da Loja,Data da Venda\n'

# %%
# Lendo o arquivo csv com o reader

import csv

dados_csv = []
with open(path_csv, 'r') as file:
    spamreader = csv.reader(file, delimiter=',')
    for row in spamreader:
        dados_csv.append(row)

# %%
# Verificando o typo de dados csv
type(dados_csv)
# Out:
# list

# %%
dados_csv[1][3]
# Out:
# '62'

# %%
# Lendo os dados em csv, porém interpretando com dicionário ao invés de listas

dados_csv = []
with open(path_csv, 'r') as file:
    spamreader = csv.DictReader(file, delimiter=',')
    for row in spamreader:
        dados_csv.append(row)

# %%
dados_csv[0]
# Out:
# {'Nome do Item': 'LÃ¡pis de sobrancelha',
#  'ClassificaÃ§Ã£o do Produto': 'Roupas',
#  'Valor em Reais (R$)': '55.17',
#  'Quantidade em Estoque': '62',
#  'Nome da Loja': 'Filial 1',
#  'Data da Venda': '2023-04-13 18:58:06.794203'}

# %%
dados_json[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
nome_colunas_json = list(dados_json[0].keys())
nome_colunas_json
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial']

# %%
nome_colunas_csv = list(dados_csv[0].keys())
nome_colunas_csv
# Out:
# ['Nome do Item',
#  'ClassificaÃ§Ã£o do Produto',
#  'Valor em Reais (R$)',
#  'Quantidade em Estoque',
#  'Nome da Loja',
#  'Data da Venda']

# %%
# Mapeando as colunas dos dados_csv e dados_json

key_mapping = {
    'Nome do Item':'Nome do Produto',
    'ClassificaÃ§Ã£o do Produto': 'Categoria do Produto',
    'Valor em Reais (R$)': 'Preço do Produto (R$)',
    'Quantidade em Estoque': 'Quantidade em Estoque',
    'Nome da Loja':'Filial',
    'Data da Venda': 'Data da Venda'
}

key_mapping
# Out:
# {'Nome do Item': 'Nome do Produto',
#  'ClassificaÃ§Ã£o do Produto': 'Categoria do Produto',
#  'Valor em Reais (R$)': 'Preço do Produto (R$)',
#  'Quantidade em Estoque': 'Quantidade em Estoque',
#  'Nome da Loja': 'Filial',
#  'Data da Venda': 'Data da Venda'}

# %%
new_dados_csv = []

for old_dict in dados_csv:
    dict_temp = {}
    for old_key, value in old_dict.items():
        dict_temp[key_mapping[old_key]] = value
    new_dados_csv.append(dict_temp)
new_dados_csv[0]
# Out:
# {'Nome do Produto': 'LÃ¡pis de sobrancelha',
#  'Categoria do Produto': 'Roupas',
#  'Preço do Produto (R$)': '55.17',
#  'Quantidade em Estoque': '62',
#  'Filial': 'Filial 1',
#  'Data da Venda': '2023-04-13 18:58:06.794203'}

# %%
# Criando uma lista que junta os dados_csv e dados_json

combined_list = []
combined_list.extend(dados_json)
combined_list.extend(new_dados_csv)

# %%
combined_list
# Out:
# [{'Nome do Produto': 'Blush em pó',
#   'Categoria do Produto': 'Eletrodomésticos',
#   'Preço do Produto (R$)': 79.41,
#   'Quantidade em Estoque': 7,
#   'Filial': 'Filial 7'},
#  {'Nome do Produto': 'Lápis de sobrancelha',
#   'Categoria do Produto': 'Eletrodomésticos',
#   'Preço do Produto (R$)': 85.47,
#   'Quantidade em Estoque': 78,
#   'Filial': 'Filial 8'},
#  {'Nome do Produto': 'Base líquida',
#   'Categoria do Produto': 'Roupas',
#   'Preço do Produto (R$)': 75.02,
#   'Quantidade em Estoque': 34,
#   'Filial': 'Filial 8'},
#  {'Nome do Produto': 'Base líquida',
#   'Categoria do Produto': 'Roupas',
#   'Preço do Produto (R$)': 44.94,
#   'Quantidade em Estoque': 90,
#   'Filial': 'Filial 10'},
#  {'Nome do Produto': 'Lápis de sobrancelha',
#   'Categoria do Produto': 'Alimentos',
#   'Preço do Produto (R$)': 58.63,
#   'Quantidade em Estoque': 91,
#   'Filial': 'Filial 7'},
#  {'Nome do Produto': 'Blush em pó',
#   'Categoria do Produto': 'Roupas',
# ...

# %%
# Atribuindo as colunas para nova lista de dados combinada, formada
nomes_colunas = list(combined_list[0].keys())
nomes_colunas
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial']

# %%
# # Gerando o arquivo com os dados combinados.

# path_dados_combinados  = '../data_processed/dados_combinados.csv'

# with open(path_dados_combinados, 'w') as file:
#     writer = csv.DictWriter(file, fieldnames=nomes_colunas)
#     writer.writeheader()

#     for row in combined_list:
#         writer.writerow(row)

# # No código é possível ver que foi gerado o problema da data da venda.

# %%
combined_list[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
combined_list[-1]['Data da Venda']
# Out:
# '2022-11-21 18:58:06.794203'

# %%
combined_list[0].get('Data da Venda', 'Indisponivel')
# Out:
# 'Indisponivel'

# %%
nomes_colunas = list(combined_list[-1].keys())
nomes_colunas
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial',
#  'Data da Venda']

# %%
dados_combinados_tabela = [nomes_colunas]

for row in combined_list:
    linha = []
    for coluna in nomes_colunas:
        linha.append(row.get(coluna, 'Indisponivel'))
    dados_combinados_tabela.append(linha)

# %%
dados_combinados_tabela
# Out:
# [['Nome do Produto',
#   'Categoria do Produto',
#   'Preço do Produto (R$)',
#   'Quantidade em Estoque',
#   'Filial',
#   'Data da Venda'],
#  ['Blush em pó', 'Eletrodomésticos', 79.41, 7, 'Filial 7', 'Indisponivel'],
#  ['Lápis de sobrancelha',
#   'Eletrodomésticos',
#   85.47,
#   78,
#   'Filial 8',
#   'Indisponivel'],
#  ['Base líquida', 'Roupas', 75.02, 34, 'Filial 8', 'Indisponivel'],
#  ['Base líquida', 'Roupas', 44.94, 90, 'Filial 10', 'Indisponivel'],
#  ['Lápis de sobrancelha', 'Alimentos', 58.63, 91, 'Filial 7', 'Indisponivel'],
#  ['Blush em pó', 'Roupas', 50.79, 77, 'Filial 7', 'Indisponivel'],
#  ['Corretivo', 'Eletrodomésticos', 20.46, 2, 'Filial 4', 'Indisponivel'],
#  ['Pó compacto', 'Roupas', 85.56, 37, 'Filial 9', 'Indisponivel'],
#  ['Sombra de olhos', 'Roupas', 31.92, 56, 'Filial 8', 'Indisponivel'],
#  ['Delineador líquido', 'Alimentos', 42.58, 8, 'Filial 3', 'Indisponivel'],
#  ['Corretivo', 'Eletrodomésticos', 92.03, 10, 'Filial 8', 'Indisponivel'],
# ...

# %%
# Gerando o arquivo csv dos dados combinados.

path_dados_combinados = '../data_processed/dados_combinados.csv'

with open(path_dados_combinados, 'w') as file:
    writer = csv.writer(file)
    writer.writerows(dados_combinados_tabela)
